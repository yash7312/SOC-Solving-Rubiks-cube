# %%
from stable_baselines3 import A2C
from stable_baselines3.common.env_util import make_vec_env

# Parallel environments
vec_env = make_vec_env("CartPole-v1", n_envs=4)

model = A2C("MlpPolicy", vec_env, verbose=1)
model.learn(total_timesteps=25000)
# Out:
# 2024-07-14 23:41:15.949822: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-14 23:41:16.356066: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-14 23:41:16.540490: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-14 23:41:16.542121: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-14 23:41:16.825219: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-14 23:41:17.787640: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Using cuda device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 18.2     |
# |    ep_rew_mean        | 18.2     |
# | time/                 |          |
# |    fps                | 1123     |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | -0.0644  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.784   |
# |    value_loss         | 20.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.4     |
# |    ep_rew_mean        | 23.4     |
# | time/                 |          |
# |    fps                | 1379     |
# |    iterations         | 200      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.605   |
# |    explained_variance | 0.066    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 1.62     |
# |    value_loss         | 6.76     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 36.9     |
# |    ep_rew_mean        | 36.9     |
# | time/                 |          |
# |    fps                | 1457     |
# |    iterations         | 300      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.594   |
# |    explained_variance | -0.00666 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 1.58     |
# |    value_loss         | 7.12     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 51.1     |
# |    ep_rew_mean        | 51.1     |
# | time/                 |          |
# |    fps                | 1527     |
# |    iterations         | 400      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.648   |
# |    explained_variance | 0.0628   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 1.25     |
# |    value_loss         | 5.97     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 67.2     |
# |    ep_rew_mean        | 67.2     |
# | time/                 |          |
# |    fps                | 1579     |
# |    iterations         | 500      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.6     |
# |    explained_variance | 0.0106   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 1.06     |
# |    value_loss         | 5.23     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 88.5     |
# |    ep_rew_mean        | 88.5     |
# | time/                 |          |
# |    fps                | 1622     |
# |    iterations         | 600      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.604   |
# |    explained_variance | 0.00774  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -0.388   |
# |    value_loss         | 57.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 104      |
# |    ep_rew_mean        | 104      |
# | time/                 |          |
# |    fps                | 1647     |
# |    iterations         | 700      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.612   |
# |    explained_variance | 0.00762  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.891    |
# |    value_loss         | 4.17     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 122      |
# |    ep_rew_mean        | 122      |
# | time/                 |          |
# |    fps                | 1642     |
# |    iterations         | 800      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.558   |
# |    explained_variance | -0.00026 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.983    |
# |    value_loss         | 3.71     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 135      |
# |    ep_rew_mean        | 135      |
# | time/                 |          |
# |    fps                | 1662     |
# |    iterations         | 900      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -0.509   |
# |    explained_variance | -0.00795 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.801    |
# |    value_loss         | 3.25     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 138      |
# |    ep_rew_mean        | 138      |
# | time/                 |          |
# |    fps                | 1677     |
# |    iterations         | 1000     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.521   |
# |    explained_variance | 0.0824   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.944    |
# |    value_loss         | 2.9      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 146      |
# |    ep_rew_mean        | 146      |
# | time/                 |          |
# |    fps                | 1691     |
# |    iterations         | 1100     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.572   |
# |    explained_variance | 0.00285  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.683    |
# |    value_loss         | 2.49     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 137      |
# |    ep_rew_mean        | 137      |
# | time/                 |          |
# |    fps                | 1674     |
# |    iterations         | 1200     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -0.563   |
# |    explained_variance | 0.778    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.596    |
# |    value_loss         | 1.65     |
# ------------------------------------

# %%
# model.save("a2c_cartpole")

# del model # remove to demonstrate saving and loading

# model = A2C.load("a2c_cartpole")

obs = vec_env.reset()
episodes = 10
score = 0
for episode in range(1,episodes+1):
    action, _states = model.predict(obs)
    obs, rewards, dones, info = vec_env.step(action)
    score += rewards
    # vec_env.render("human")
print(score)
# Out:
# [10. 10. 10. 10.]
